# %%
# pick random points in the unit square ((0, 0) to (1,1)) and 
# see how many fall in the unit circle
# This should be Pi / 4.
from random import random
from operator import add

n = 1000000

# A function to generate 2 random numbers
# Check if x^2 + y^2 < 1 and return true/false
    

# Create a variable called count, assign a range (1, n + 1)
# Use a map to apply the function and finally count the number of successes


# Pi is defined as 4 * count / n
# Print the value of Pi.
