# %%
# Import Python Regular Expression module
import re
# Define a function to remove any special characters
def removePunctuation(text):
    """Removes punctuation, changes to lower case, and strips leading and trailing spaces.
    Note:
        Only spaces, letters, and numbers should be retained.  Other characters should should be
        eliminated (e.g. it's becomes its).  Leading and trailing spaces should be removed after
        punctuation is removed.
    Args:
        text (str): A string.
    Returns:
        str: The cleaned up string.
    """
    return re.sub(r'[^a-z0-9\s]','',text.lower().strip())

# Load the two-cities corpus from the Azure storage blob (/user/livy/two-cities.txt)

# Word count create a flatMap to split over space (" "), then map each word to 1.
# Finally use a `reduceByKey` operation to add the values.
# Optionally a filter could be used to extract only those words with more than 10 occurrences

# Print words and counts
