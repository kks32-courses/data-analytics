# %%
# pick random points in the unit square ((0, 0) to (1,1)) and 
# see how many fall in the unit circle
# This should be Pi / 4.
from random import random
from operator import add

n = 100000 

def f(_):
    x, y = random(), random()
    return (x * x + y * y < 1)

count = sc.parallelize(range(1, n + 1)).map(f).reduce(add)
print("Pi is roughly %f" % (4.0 * count / n))
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>9</td><td>application_1499674741924_0013</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://hn1-kbtu.3bs2jaxxb12u1ll00rolucu4sg.ax.internal.cloudapp.net:8088/proxy/application_1499674741924_0013/">Link</a></td><td><a target="_blank" href="http://10.0.0.12:30060/node/containerlogs/container_1499674741924_0013_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# Pi is roughly 3.140160
